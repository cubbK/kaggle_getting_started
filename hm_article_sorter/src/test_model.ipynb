# %%
from transformers import pipeline

pipe = pipeline("image-classification", model="cubbk/dinov2-base-finetuned-clothes-big")
pipe("https://static.zara.net/assets/public/bfee/addd/413e4fcc9fc2/f6d8e18c39c3/00653625600-e1/00653625600-e1.jpg?ts=1752067736279&w=1500")
# Out:
# Device set to use mps:0
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[4], line 4
#       1 from transformers import pipeline
#       3 pipe = pipeline("image-classification", model="cubbk/dinov2-base-finetuned-clothes-big")
# ----> 4 pipe("https://static.zara.net/assets/public/bfee/addd/413e4fcc9fc2/f6d8e18c39c3/00653625600-e1/00653625600-e1.jpg?ts=1752067736279&w=1500")
#
# File ~/work/kaggle_getting_started/hm_article_sorter/.venv/lib/python3.11/site-packages/transformers/pipelines/image_classification.py:189, in ImageClassificationPipeline.__call__(self, inputs, **kwargs)
#     187 if inputs is None:
#     188     raise ValueError("Cannot call the image-classification pipeline without an inputs argument!")
# --> 189 return super().__call__(inputs, **kwargs)
#
# File ~/work/kaggle_getting_started/hm_article_sorter/.venv/lib/python3.11/site-packages/transformers/pipelines/base.py:1458, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1450     return next(
#    1451         iter(
#    1452             self.get_iterator(
#    (...)   1455         )
#    1456     )
#    1457 else:
# -> 1458     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~/work/kaggle_getting_started/hm_article_sorter/.venv/lib/python3.11/site-packages/transformers/pipelines/base.py:1464, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1463 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
# -> 1464     model_inputs = self.preprocess(inputs, **preprocess_params)
#    1465     model_outputs = self.forward(model_inputs, **forward_params)
#    1466     outputs = self.postprocess(model_outputs, **postprocess_params)
#
# File ~/work/kaggle_getting_started/hm_article_sorter/.venv/lib/python3.11/site-packages/transformers/pipelines/image_classification.py:192, in ImageClassificationPipeline.preprocess(self, image, timeout)
#     191 def preprocess(self, image, timeout=None):
# --> 192     image = load_image(image, timeout=timeout)
#     193     model_inputs = self.image_processor(images=image, return_tensors=self.framework)
#     194     if self.framework == "pt":
#
# File ~/work/kaggle_getting_started/hm_article_sorter/.venv/lib/python3.11/site-packages/transformers/image_utils.py:475, in load_image(image, timeout)
#     471 if isinstance(image, str):
#     472     if image.startswith("http://") or image.startswith("https://"):
#     473         # We need to actually check for a real protocol, otherwise it's impossible to use a local file
#     474         # like http_huggingface_co.png
# --> 475         image = PIL.Image.open(BytesIO(requests.get(image, timeout=timeout).content))
#     476     elif os.path.isfile(image):
#     477         image = PIL.Image.open(image)
#
# File ~/work/kaggle_getting_started/hm_article_sorter/.venv/lib/python3.11/site-packages/PIL/Image.py:3580, in open(fp, mode, formats)
#    3578     warnings.warn(message)
#    3579 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3580 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x15a499990>
