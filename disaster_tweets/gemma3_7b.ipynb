# %%
import json
import os

# Load Kaggle API credentials from kaggle_key.json
with open('kaggle_key.json', 'r') as f:
    kaggle_credentials = json.load(f)

# Set Kaggle API credentials as environment variables
os.environ['KAGGLE_USERNAME'] = kaggle_credentials['username']
os.environ['KAGGLE_KEY'] = kaggle_credentials['key']

print("Kaggle API credentials loaded successfully!")
print(f"Username: {kaggle_credentials['username']}")
print("Key: ****" + kaggle_credentials['key'][-4:])  # Show only last 4 characters for security

# %%
import pandas as pd

# Load the training data
df = pd.read_csv('data/train.csv')

df

# %%
import os

os.environ["KERAS_BACKEND"] = "jax"
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"]="1.00"

import keras
import keras_hub

gemma_lm = keras_hub.models.Gemma3CausalLM.from_preset("gemma3_instruct_4b_text")
gemma_lm.summary()
# Out:
# 2025-08-06 21:37:04.049795: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754509024.065190    2185 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754509024.070122    2185 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1754509024.082798    2185 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
gemma_lm.backbone.enable_lora(rank=4) # type: ignore
gemma_lm.summary()
# Out:
# Preprocessor: "gemma3_causal_lm_preprocessor"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                                                  ┃                                   Config ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ gemma3_tokenizer (Gemma3Tokenizer)                            │                      Vocab size: 262,144 │
# └───────────────────────────────────────────────────────────────┴──────────────────────────────────────────┘
# Model: "gemma3_causal_lm"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# ...

# %%
template = "Tweet: {tweet}\nIs this about a real disaster? Answer Yes or No\nAnswer:"

data = {
    "prompts": df["text"].map(lambda x: template.format(tweet=x)).tolist(),
    "responses": df["target"].map(lambda x: "Yes" if x == 1 else "No")
}

data_small = {
    "prompts": df["text"].head(100).map(lambda x: template.format(tweet=x)).tolist(),
    "responses": df["target"].head(100).map(lambda x: "Yes" if x == 1 else "No").tolist()
}

# %%
# Limit the input sequence length to 256 (to control memory usage).
gemma_lm.preprocessor.sequence_length = 256 # type: ignore
# Use AdamW (a common optimizer for transformer models).
optimizer = keras.optimizers.AdamW(
    learning_rate=1e-5,
    weight_decay=0.01,
)
# Exclude layernorm and bias terms from decay.
optimizer.exclude_from_weight_decay(var_names=["bias", "scale"])

gemma_lm.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True), # type: ignore
    optimizer=optimizer, # type: ignore
    weighted_metrics=[keras.metrics.SparseCategoricalAccuracy()]
)

keras.mixed_precision.set_global_policy('mixed_bfloat16')
gemma_lm.fit(data, epochs=1, batch_size=1)
# Out:
# 2025-08-06 21:43:32.572654: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3023] Can't reduce memory use below 7.16GiB (7683385254 bytes) by rematerialization; only reduced to 17.38GiB (18662125008 bytes), down from 17.38GiB (18666325080 bytes) originally
#    1/7613 ━━━━━━━━━━━━━━━━━━━━ 77:45:12 37s/step - loss: 0.0695 - sparse_categorical_accuracy: 0.0000e+00
# 2025-08-06 21:44:05.611283: W external/xla/xla/hlo/transforms/simplifiers/hlo_rematerialization.cc:3023] Can't reduce memory use below 7.16GiB (7683385254 bytes) by rematerialization; only reduced to 17.38GiB (18662125008 bytes), down from 17.38GiB (18666325080 bytes) originally
# 7613/7613 ━━━━━━━━━━━━━━━━━━━━ 2798s 363ms/step - loss: 0.0036 - sparse_categorical_accuracy: 0.8629

# %%
gemma_lm.backbone.save_lora_weights("trained_gemma_4b_disaster_lora.lora.h5")

# %%
prompt = template.format(tweet="The party is blasting! Going to get wrecked tonight!")

response = gemma_lm.generate(prompt, max_length=len(prompt) + 4)
print(response)
print(df.iloc[102]['target'])
# Out:
# Tweet: The party is blasting! Going to get wrecked tonight!
# Is this about a real disaster? Answer Yes or No
# Answer:No
# 0
